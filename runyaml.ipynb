# %%
# %%bash
#
# cd /project/chihway/junzhou
#
# source "$(./miniconda3/bin/conda info --base)/etc/profile.d/conda.sh"
#
# conda activate cocoa
#
# cd ./Code-comparison/cocoa/Cocoa
#
# source ./start_cocoa.sh
#
# export OMP_NUM_THREADS=12; export OMP_PROC_BIND=close; export OMP_PLACES=cores; export OMP_DYNAMIC=FALSE
#
# mpirun -n 1 --oversubscribe --mca pml ^ucx --mca btl vader,tcp,self \
#    --bind-to core:overload-allowed --mca mpi_yield_when_idle 1 --report-bindings  \
#    --rank-by slot --map-by numa:pe=${OMP_NUM_THREADS} \
#    cobaya-run ./projects/desy3_real/desy3_baseline_evaluate.yaml -f
# Out:
# [midway3-0223.rcc.local:197342] Rank 0 bound to package[0][core:0-11]
# [output] Output to be read-from/written-into folder './projects/desy3_real/chains/desy3_baseline_evaluate', with prefix ''
# [camb] `camb` module loaded successfully from /project/chihway/junzhou/Code-comparison/cocoa/Cocoa/external_modules/code/CAMB/camb
# [desy3_real.combo_3x2pt]  implement_bin_average = 1
# [desy3_real.combo_3x2pt]  adopt_nolimber_gg = 1
# [desy3_real.combo_3x2pt]  lmax_nolimber = 150
# [desy3_real.combo_3x2pt]  adopt_RSD_gg = 1
# [desy3_real.combo_3x2pt]  adopt_RSD_gs = 1
# [desy3_real.combo_3x2pt]  NCell_interpolation = 300
# [desy3_real.combo_3x2pt]  Na_interpolation = 225
# [desy3_real.combo_3x2pt] use_baryon_pca = False
# [evaluate] Initialized!
# [evaluate] Looking for a reference point with non-zero prior.
# [evaluate] Reference point:
#    As_1e9 = 2.1
#    ns = 0.96605
#    H0 = 67.32
#    omegab = 0.04
#    omegam = 0.3
#    mnu = 0.06
#    w0pwa = -0.9
#    w = -0.9
#    DES_DZ_S1 = 0.0414632
#    DES_DZ_S2 = 0.00147332
#    DES_DZ_S3 = 0.0237035
#    DES_DZ_S4 = -0.0773436
#    DES_M1 = 0.0191832
#    DES_M2 = -0.0431752
#    DES_M3 = -0.034961
#    DES_M4 = -0.0158096
#    DES_A1_1 = 0.606102
#    DES_A1_2 = -1.51541
#    DES_A2_1 = 0.01
#    DES_A2_2 = -1.54481
#    DES_BTA_1 = 0.815401
#    DES_DZ_L1 = 0.00457604
#    DES_DZ_L2 = 0.000309875
#    DES_DZ_L3 = 0.00855907
#    DES_DZ_L4 = -0.00316269
#    DES_DZ_L5 = -0.0146753
#    DES_B1_1 = 1.72716
#    DES_B1_2 = 1.65168
#    DES_B1_3 = 1.61423
#    DES_B1_4 = 1.92886
#    DES_B1_5 = 2.11633
# [evaluate] Evaluating prior and likelihoods...
# [evaluate] log-posterior  = -455.221
# [evaluate] log-prior      = 5.67278
# [evaluate]    logprior_0 = 5.67278
# [evaluate] log-likelihood = -460.894
# [evaluate]    chi2_desy3_real.combo_3x2pt = 921.788
# [evaluate] Derived params:
# [evaluate]    As = 2.1e-09
# [evaluate]    wa = 0
# [evaluate]    omegabh2 = 0.0181279
# [evaluate]    omegach2 = 0.117186
# [evaluate]    omegal = 0.699921
# [evaluate]    omegamh2 = 0.135959
# [evaluate]    sigma8 = 0.803966
# [evaluate]    s8h5 = 0.979863
# [evaluate]    s8omegamp5 = 0.44035
# [evaluate]    s8omegamp25 = 0.595001
# [evaluate]    age = 13.7692
# [evaluate]    rdrag = 152.88
# [evaluate]    yheused = 0.243824
# [evaluate]    omegan2 = 0.000644867
# [evaluate]    omegan = 0.00142292
# [desy3_real.combo_3x2pt] Average evaluation time for desy3_real.combo_3x2pt: 0.723573 s  (1 evaluations)
# [camb.transfers] Average evaluation time for camb.transfers: 0.442809 s  (1 evaluations)
# [camb] Average evaluation time for camb: 0.513132 s  (1 evaluations)
